# %% [markdown]
# **17.1. MedBuddy.ML - Heart Disease Risk Prediction**

# %% [markdown]
# Dataset: `heart.csv`

# %% [markdown]
# **1. Setup**

# %%
# install required libraries - can also be executed in the terminal in .venv
# %pip install -r requirements.txt

# %%
# importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import randint, uniform

from sklearn.model_selection import GroupShuffleSplit, StratifiedGroupKFold, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    recall_score,
    f1_score,
)

# %%
# configurations
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", lambda x: f"{x:.3f}")
sns.set_theme(style="darkgrid")

RANDOM_STATE = 42
CSV_PATH="/Volumes/MyDrive/3_udemy/2_ml_course/udemy-2-ml-course-rec-code/section_17_capstone_projects/ml-17-1-med-buddy-ml/dataset/heart.csv"
TARGET_COL="target"

# %% [markdown]
# **2. Load Data**

# %%
df = pd.read_csv(CSV_PATH)
print("Dataset shape:", df.shape)
display(df.head())
# Out:
# Dataset shape: (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0    1.000      2
# 1   53    1   0       140   203    1        0      155      1    3.100      0
# 2   70    1   0       145   174    0        1      125      1    2.600      0
# 3   61    1   0       148   203    0        1      161      0    0.000      2
# 4   62    0   0       138   294    1        1      106      0    1.900      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# | Column Name | Short Description | Feature Type |
# |------------|-------------------|--------------|
# | age | Age of the patient (in years) | Numerical |
# | sex | Sex of the patient (1 = male, 0 = female) | Categorical |
# | cp | Chest pain type (0–3 representing different chest pain categories) | Categorical |
# | trestbps | Resting blood pressure (in mm Hg) | Numerical |
# | chol | Serum cholesterol level (in mg/dl) | Numerical |
# | fbs | Fasting blood sugar > 120 mg/dl (1 = true, 0 = false) | Categorical |
# | restecg | Resting electrocardiographic results (0–2) | Categorical |
# | thalach | Maximum heart rate achieved | Numerical |
# | exang | Exercise-induced angina (1 = yes, 0 = no) | Categorical |
# | oldpeak | ST depression induced by exercise relative to rest | Numerical |
# | slope | Slope of the peak exercise ST segment (0–2) | Categorical |
# | ca | Number of major vessels colored by fluoroscopy (0–4) | Numerical |
# | thal | Thalassemia status (0 = normal, 1 = fixed defect, 2 = reversible defect, 3 = unknown) | Categorical |
# | target | Presence of heart disease (1 = disease, 0 = no disease) | Categorical |

# %% [markdown]
# >NOTE: Categorical columns are encoded already

# %% [markdown]
# **3. Exploratory Data Analysis**

# %%
# basic dataset overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
numerical_features = [
    "age",
    "trestbps",
    "chol",
    "thalach",
    "oldpeak",
    "ca"
]

categorical_features = [
    "sex",
    "cp",
    "fbs",
    "restecg",
    "exang",
    "slope",
    "thal",
    "target"
]

print("Numerical features:", numerical_features)
print("Categorical features:", categorical_features)
# Out:
# Numerical features: ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca']
# Categorical features: ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal', 'target']

# %%
# missing values
df.isna().sum().sort_values()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# quick checks for encoded missing values
for col in df.columns:
    print(df[col].value_counts().head(10))
# Out:
# age
# 58    68
# 57    57
# 54    53
# 59    46
# 52    43
# 51    39
# 56    39
# 62    37
# 60    37
# 44    36
# Name: count, dtype: int64
# sex
# 1    713
# 0    312
# Name: count, dtype: int64
# cp
# 0    497
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64
# trestbps
# 120    128
# 130    123
# 140    107
# 110     64
# 150     55
# 138     45
# 128     39
# 125     38
# 160     36
# 112     30
# Name: count, dtype: int64
# chol
# 204    21
# 234    21
# 197    19
# 212    18
# 254    17
# 269    16
# 177    14
# 240    14
# 282    14
# 239    13
# Name: count, dtype: int64
# fbs
# 0    872
# 1    153
# Name: count, dtype: int64
# restecg
# 1    513
# 0    497
# 2     15
# Name: count, dtype: int64
# thalach
# 162    35
# 160    31
# 163    29
# 173    28
# 152    28
# 144    26
# 132    26
# 150    25
# 125    25
# 143    23
# Name: count, dtype: int64
# exang
# 0    680
# 1    345
# Name: count, dtype: int64
# oldpeak
# 0.000    329
# 1.200     58
# 1.000     51
# 0.600     47
# 0.800     44
# 1.400     44
# 1.600     37
# 0.200     37
# 1.800     36
# 2.000     32
# Name: count, dtype: int64
# slope
# 1    482
# 2    469
# 0     74
# Name: count, dtype: int64
# ca
# 0    578
# 1    226
# 2    134
# 3     69
# 4     18
# Name: count, dtype: int64
# thal
# 2    544
# 3    410
# 1     64
# 0      7
# Name: count, dtype: int64
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %% [markdown]
# >NOTE: No missing values or encoded missing values

# %%
# duplicates
duplicate_mask = df.duplicated()
num_duplicates = duplicate_mask.sum()
print("Number of duplicate rows:", num_duplicates)

# (optional) drop duplicates if present
# df = df.drop_duplicates()
# print("Shape after dropping duplicates:", df.shape)
# Out:
# Number of duplicate rows: 723

# %% [markdown]
# >Although the dataset contains a large number of duplicate rows, these likely represent multiple real-world patients with identical clinical measurements. Dropping these rows would drastically reduce the dataset size and distort the natural frequency of observations in the data.
#
# >We therefore retain duplicate rows, but take special care during validation. To ensure a fair evaluation, we use group-based splitting (Group K-Fold) so that identical data points are never shared between training and validation folds.
#
# >While tree-based models are robust to duplicate observations during training, preventing duplicate leakage across folds is essential to obtain reliable and unbiased performance estimates.

# %%
# target distribution
print(df[TARGET_COL].value_counts())
print("-"*50)
print(df[TARGET_COL].value_counts(normalize=True) * 100)
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64
# --------------------------------------------------
# target
# 1   51.317
# 0   48.683
# Name: proportion, dtype: float64

# %% [markdown]
# >Even class distribution

# %%
df[numerical_features].describe()
# Out:
#            age  trestbps     chol  thalach  oldpeak       ca
# count 1025.000  1025.000 1025.000 1025.000 1025.000 1025.000
# mean    54.434   131.612  246.000  149.114    1.072    0.754
# std      9.072    17.517   51.593   23.006    1.175    1.031
# min     29.000    94.000  126.000   71.000    0.000    0.000
# 25%     48.000   120.000  211.000  132.000    0.000    0.000
# 50%     56.000   130.000  240.000  152.000    0.800    0.000
# 75%     61.000   140.000  275.000  166.000    1.800    1.000
# max     77.000   200.000  564.000  202.000    6.200    4.000

# %%
# visualize target distribution
plt.figure(figsize=(4, 3))
sns.countplot(x=TARGET_COL, data=df)
plt.title("Class Distribution (0 = No heart disease, 1 = Heart disease)")
plt.show()

# %%
# histogram plot - distribution - for numerical features
fig, axes = plt.subplots(3, 2, figsize=(6, 4))
axes = axes.flatten()

for i, col in enumerate(numerical_features):
    sns.histplot(df[col], kde=True, ax=axes[i])
    axes[i].set_title(col, fontsize=8)

plt.tight_layout()
plt.show()

# %%
# outliers analysis - boxplot
fig, axes = plt.subplots(3, 2, figsize=(6, 4))
axes = axes.flatten()

for i, col in enumerate(numerical_features):
    sns.boxplot(x=df[col], ax=axes[i])
    axes[i].set_title(col, fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# >Not much outliers. We can leave it as is

# %%
# identify presence of highly correlated columns & feature relationships
plt.figure(figsize=(8, 5))
sns.heatmap(
    df[numerical_features].corr(),
    cmap="coolwarm",
    annot=True,
    fmt=".1f",
    center=0
)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# **No highly correlated columns**

# %% [markdown]
# **4. Data Preprocessing**

# %%
# Separate X and y
X = df.drop(columns=[TARGET_COL])
y = df[TARGET_COL]

# Create a signature for each feature row - to prevent duplicates flow to test set
row_signature = pd.util.hash_pandas_object(X, index=False)

# %%
# Split data into train and test sets using GroupShuffleSplit
gss = GroupShuffleSplit(
    n_splits=1,
    test_size=0.15,
    random_state=RANDOM_STATE
)

train_idx, test_idx = next(
    gss.split(X, y, groups=row_signature)
)

X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (869, 13)
# Test shape: (156, 13)

# %%
print("Dataset size", X.shape)
print("Train Dataset size", X_train.shape)
print("Test Dataset size", X_test.shape)
# Out:
# Dataset size (1025, 13)
# Train Dataset size (869, 13)
# Test Dataset size (156, 13)

# %% [markdown]
# **5. Baseline Model - Logistic Regression**

# %%
base_pipe = Pipeline(
    steps=[
        ("scaler", StandardScaler()),
        ("model", LogisticRegression())
    ]
)

# %%
# training the base pipeline
base_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', LogisticRegression())])

# %%
# reusable evaluation function
def evaluate_classifier(model, X_train, y_train, X_test, y_test, model_name):
    # predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # accuracy
    train_acc = accuracy_score(y_train, y_train_pred) * 100
    test_acc = accuracy_score(y_test, y_test_pred) * 100

    # results
    print(f"{model_name} - Train Accuracy: {train_acc:.2f}%")
    print(f"{model_name} - Test Accuracy: {test_acc:.2f}%\n")

    print("-"*40)

    print("Train Classification Report")
    print(classification_report(y_train, y_train_pred))

    print("-"*40)

    print("Test Classification Report")
    print(classification_report(y_test, y_test_pred))

# %%
evaluate_classifier(
    base_pipe,
    X_train,
    y_train,
    X_test,
    y_test,
    model_name="Logistic Regression - Base Model"
)
# Out:
# Logistic Regression - Base Model - Train Accuracy: 84.23%
# Logistic Regression - Base Model - Test Accuracy: 83.33%
#
# ----------------------------------------
# Train Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83       430
#            1       0.81      0.89      0.85       439
#
#     accuracy                           0.84       869
#    macro avg       0.85      0.84      0.84       869
# weighted avg       0.85      0.84      0.84       869
#
# ----------------------------------------
# Test Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.71      0.79        69
#            1       0.80      0.93      0.86        87
#
#     accuracy                           0.83       156
#    macro avg       0.85      0.82      0.83       156
# weighted avg       0.84      0.83      0.83       156

# %% [markdown]
# >Descent Performance. Can be improved.

# %% [markdown]
# **6. Model Selection**

# %%
# models to evaluate
models = {
    "Logistic Regression": LogisticRegression(random_state=RANDOM_STATE),
    "Support Vector Machine": SVC(random_state=RANDOM_STATE),
    "Random Forest": RandomForestClassifier(random_state=RANDOM_STATE),
    "XGBoost": XGBClassifier()
}

# %%
groups = pd.util.hash_pandas_object(X_train, index=False)

k = 5
cv = StratifiedGroupKFold(n_splits=k, shuffle=True, random_state=RANDOM_STATE)

# %%
for name, model in models.items():

    recall_scores = []
    f1_scores = []

    for tr_idx, te_idx in cv.split(X_train, y_train, groups=groups):
        X_tr, X_te = X_train.iloc[tr_idx], X_train.iloc[te_idx]
        y_tr, y_te = y_train.iloc[tr_idx], y_train.iloc[te_idx]

        pipeline = Pipeline(
            steps=[
                ("scaler", StandardScaler()),
                ("model", model)
            ]
        )

        pipeline.fit(X_tr, y_tr)
        pred = pipeline.predict(X_te)

        recall_scores.append(round(recall_score(y_te, pred), 2))
        f1_scores.append(round(f1_score(y_te, pred), 2))

    print("Model name:", name)
    print("Recall values:", recall_scores)
    print("F1 scores:", f1_scores)
    print("\nCV Recall mean:", round(float(np.mean(recall_scores)), 4))
    print("CV F1 Score mean:", round(float(np.mean(f1_scores)), 4))
    print("-"*50)

# cross validation is a more reliable validation technique than a simple train-test split
# Out:
# Model name: Logistic Regression
# Recall values: [0.9, 0.75, 0.93, 0.89, 0.82]
# F1 scores: [0.87, 0.75, 0.91, 0.82, 0.75]
#
# CV Recall mean: 0.858
# CV F1 Score mean: 0.82
# --------------------------------------------------
# Model name: Support Vector Machine
# Recall values: [0.79, 0.72, 0.82, 0.96, 0.72]
# F1 scores: [0.76, 0.76, 0.84, 0.83, 0.69]
#
# CV Recall mean: 0.802
# CV F1 Score mean: 0.776
# --------------------------------------------------
# Model name: Random Forest
# Recall values: [0.93, 0.82, 0.9, 0.92, 0.82]
# F1 scores: [0.88, 0.81, 0.87, 0.87, 0.75]
#
# CV Recall mean: 0.878
# CV F1 Score mean: 0.836
# --------------------------------------------------
# Model name: XGBoost
# Recall values: [0.82, 0.72, 0.9, 0.97, 0.82]
# F1 scores: [0.79, 0.78, 0.86, 0.87, 0.72]
#
# CV Recall mean: 0.846
# CV F1 Score mean: 0.804
# --------------------------------------------------

# %% [markdown]
# >**RandomForestClassifier** provides the highest performance

# %% [markdown]
# **Hyperparameter Tuning - RFC**

# %%
rfc_pipe = Pipeline(
    steps=[
        ("scaler", StandardScaler()),
        ("model", RandomForestClassifier(
            random_state=RANDOM_STATE,
            n_jobs=-1,
        ))
    ]
)

# %%
# parameter distributions
param_dist = {
    "model__n_estimators": randint(400, 1200),
    "model__max_depth": [3, 4, 5, 6],
    "model__min_samples_split": randint(10, 40),
    "model__min_samples_leaf": randint(4, 20),
    "model__max_features": [0.25, 0.35, 0.5, "sqrt"],
    "model__bootstrap": [True],
    "model__max_samples": uniform(0.6, 0.35),
    "model__ccp_alpha": uniform(0.0, 0.02),
}

# %%
# randomized search
random_search = RandomizedSearchCV(
    estimator=rfc_pipe,
    param_distributions=param_dist,
    n_iter=60,
    scoring="f1_macro",
    cv=cv,
    random_state=RANDOM_STATE,
    verbose=2,
    n_jobs=-1
)

# %%
# performing gridsearchcv
random_search.fit(X_train, y_train, groups=groups)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00749080237694725, model__max_depth=3, model__max_features=0.5, model__max_samples=0.8561978796339917, model__min_samples_leaf=16, model__min_samples_split=30, model__n_estimators=1014; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.008916655057071824, model__max_depth=5, model__max_features=0.5, model__max_samples=0.7607371121880535, model__min_samples_leaf=8, model__min_samples_split=13, model__n_estimators=1063; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.008916655057071824, model__max_depth=5, model__max_features=0.5, model__max_samples=0.7607371121880535, model__min_samples_leaf=8, model__min_samples_split=13, model__n_estimators=1063; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.008916655057071824, model__max_depth=5, model__max_features=0.5, model__max_samples=0.7607371121880535, model__min_samples_leaf=8, model__min_samples_split=13, model__n_estimators=1063; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00749080237694725, model__max_depth=3, model__max_features=0.5, model__max_samples=0.8561978796339917, model__min_samples_leaf=16, model__min_samples_split=30, model__n_estimators=1014; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00749080237694725, model__max_depth=3, model__max_features=0.5, model__max_samples=0.8561978796339917, model__min_samples_leaf=16, model__min_samples_split=30, model__n_estimators=1014; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00749080237694725, model__max_depth=3, model__max_features=0.5, model__max_samples=0.8561978796339917, model__min_samples_leaf=16, model__min_samples_split=30, model__n_estimators=1014; total time=   2.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00749080237694725, model__max_depth=3, model__max_features=0.5, model__max_samples=0.8561978796339917, model__min_samples_leaf=16, model__min_samples_split=30, model__n_estimators=1014; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.008916655057071824, model__max_depth=5, model__max_features=0.5, model__max_samples=0.7607371121880535, model__min_samples_leaf=8, model__min_samples_split=13, model__n_estimators=1063; total time=   2.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.008916655057071824, model__max_depth=5, model__max_features=0.5, model__max_samples=0.7607371121880535, model__min_samples_leaf=8, model__min_samples_split=13, model__n_estimators=1063; total time=   2.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.013017769458977058, model__max_depth=3, model__max_features=0.35, model__max_samples=0.8526995702933886, model__min_samples_leaf=17, model__min_samples_split=15, model__n_estimators=785; total time=   1.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.013017769458977058, model__max_depth=3, model__max_features=0.35, model__max_samples=0.8526995702933886, model__min_samples_leaf=17, model__min_samples_split=15, model__n_estimators=785; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.013017769458977058, model__max_depth=3, model__max_features=0.35, model__max_samples=0.8526995702933886, model__min_samples_leaf=17, model__min_samples_split=15, model__n_estimators=785; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.013017769458977058, model__max_depth=3, model__max_features=0.35, model__max_samples=0.8526995702933886, model__min_samples_leaf=17, model__min_samples_split=15, model__n_estimators=785; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.013017769458977058, model__max_depth=3, model__max_features=0.35, model__max_samples=0.8526995702933886, model__min_samples_leaf=17, model__min_samples_split=15, model__n_estimators=785; total time=   1.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0036364993441420123, model__max_depth=3, model__max_features=0.25, model__max_samples=0.7064847850358382, model__min_samples_leaf=9, model__min_samples_split=38, model__n_estimators=1147; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0036364993441420123, model__max_depth=3, model__max_features=0.25, model__max_samples=0.7064847850358382, model__min_samples_leaf=9, model__min_samples_split=38, model__n_estimators=1147; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0036364993441420123, model__max_depth=3, model__max_features=0.25, model__max_samples=0.7064847850358382, model__min_samples_leaf=9, model__min_samples_split=38, model__n_estimators=1147; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0036364993441420123, model__max_depth=3, model__max_features=0.25, model__max_samples=0.7064847850358382, model__min_samples_leaf=9, model__min_samples_split=38, model__n_estimators=1147; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00046124850082831517, model__max_depth=5, model__max_features=0.5, model__max_samples=0.7399513401003394, model__min_samples_leaf=19, model__min_samples_split=37, model__n_estimators=1099; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00046124850082831517, model__max_depth=5, model__max_features=0.5, model__max_samples=0.7399513401003394, model__min_samples_leaf=19, model__min_samples_split=37, model__n_estimators=1099; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00046124850082831517, model__max_depth=5, model__max_features=0.5, model__max_samples=0.7399513401003394, model__min_samples_leaf=19, model__min_samples_split=37, model__n_estimators=1099; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00046124850082831517, model__max_depth=5, model__max_features=0.5, model__max_samples=0.7399513401003394, model__min_samples_leaf=19, model__min_samples_split=37, model__n_estimators=1099; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0036364993441420123, model__max_depth=3, model__max_features=0.25, model__max_samples=0.7064847850358382, model__min_samples_leaf=9, model__min_samples_split=38, model__n_estimators=1147; total time=   3.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00046124850082831517, model__max_depth=5, model__max_features=0.5, model__max_samples=0.7399513401003394, model__min_samples_leaf=19, model__min_samples_split=37, model__n_estimators=1099; total time=   2.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.007327236865873834, model__max_depth=4, model__max_features=0.35, model__max_samples=0.8748115864875547, model__min_samples_leaf=6, model__min_samples_split=21, model__n_estimators=966; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.007327236865873834, model__max_depth=4, model__max_features=0.35, model__max_samples=0.8748115864875547, model__min_samples_leaf=6, model__min_samples_split=21, model__n_estimators=966; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.007327236865873834, model__max_depth=4, model__max_features=0.35, model__max_samples=0.8748115864875547, model__min_samples_leaf=6, model__min_samples_split=21, model__n_estimators=966; total time=   2.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019664617716135764, model__max_depth=3, model__max_features=0.5, model__max_samples=0.9009791423577121, model__min_samples_leaf=10, model__min_samples_split=30, model__n_estimators=566; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.007327236865873834, model__max_depth=4, model__max_features=0.35, model__max_samples=0.8748115864875547, model__min_samples_leaf=6, model__min_samples_split=21, model__n_estimators=966; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019664617716135764, model__max_depth=3, model__max_features=0.5, model__max_samples=0.9009791423577121, model__min_samples_leaf=10, model__min_samples_split=30, model__n_estimators=566; total time=   1.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019664617716135764, model__max_depth=3, model__max_features=0.5, model__max_samples=0.9009791423577121, model__min_samples_leaf=10, model__min_samples_split=30, model__n_estimators=566; total time=   1.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019664617716135764, model__max_depth=3, model__max_features=0.5, model__max_samples=0.9009791423577121, model__min_samples_leaf=10, model__min_samples_split=30, model__n_estimators=566; total time=   1.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.007327236865873834, model__max_depth=4, model__max_features=0.35, model__max_samples=0.8748115864875547, model__min_samples_leaf=6, model__min_samples_split=21, model__n_estimators=966; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019664617716135764, model__max_depth=3, model__max_features=0.5, model__max_samples=0.9009791423577121, model__min_samples_leaf=10, model__min_samples_split=30, model__n_estimators=566; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00026529922319733055, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7971508762459387, model__min_samples_leaf=13, model__min_samples_split=18, model__n_estimators=745; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00026529922319733055, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7971508762459387, model__min_samples_leaf=13, model__min_samples_split=18, model__n_estimators=745; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00026529922319733055, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7971508762459387, model__min_samples_leaf=13, model__min_samples_split=18, model__n_estimators=745; total time=   1.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00026529922319733055, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7971508762459387, model__min_samples_leaf=13, model__min_samples_split=18, model__n_estimators=745; total time=   1.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00026529922319733055, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7971508762459387, model__min_samples_leaf=13, model__min_samples_split=18, model__n_estimators=745; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0019534422801276772, model__max_depth=6, model__max_features=sqrt, model__max_samples=0.7540533728088604, model__min_samples_leaf=10, model__min_samples_split=21, model__n_estimators=908; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0019534422801276772, model__max_depth=6, model__max_features=sqrt, model__max_samples=0.7540533728088604, model__min_samples_leaf=10, model__min_samples_split=21, model__n_estimators=908; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0019534422801276772, model__max_depth=6, model__max_features=sqrt, model__max_samples=0.7540533728088604, model__min_samples_leaf=10, model__min_samples_split=21, model__n_estimators=908; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0019534422801276772, model__max_depth=6, model__max_features=sqrt, model__max_samples=0.7540533728088604, model__min_samples_leaf=10, model__min_samples_split=21, model__n_estimators=908; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0019534422801276772, model__max_depth=6, model__max_features=sqrt, model__max_samples=0.7540533728088604, model__min_samples_leaf=10, model__min_samples_split=21, model__n_estimators=908; total time=   2.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.016663898234723286, model__max_depth=5, model__max_features=0.35, model__max_samples=0.7368712126506343, model__min_samples_leaf=5, model__min_samples_split=17, model__n_estimators=787; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.016663898234723286, model__max_depth=5, model__max_features=0.35, model__max_samples=0.7368712126506343, model__min_samples_leaf=5, model__min_samples_split=17, model__n_estimators=787; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.016663898234723286, model__max_depth=5, model__max_features=0.35, model__max_samples=0.7368712126506343, model__min_samples_leaf=5, model__min_samples_split=17, model__n_estimators=787; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.016663898234723286, model__max_depth=5, model__max_features=0.35, model__max_samples=0.7368712126506343, model__min_samples_leaf=5, model__min_samples_split=17, model__n_estimators=787; total time=   1.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.016663898234723286, model__max_depth=5, model__max_features=0.35, model__max_samples=0.7368712126506343, model__min_samples_leaf=5, model__min_samples_split=17, model__n_estimators=787; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01684569549189997, model__max_depth=6, model__max_features=0.35, model__max_samples=0.7383025826006351, model__min_samples_leaf=7, model__min_samples_split=23, model__n_estimators=670; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01684569549189997, model__max_depth=6, model__max_features=0.35, model__max_samples=0.7383025826006351, model__min_samples_leaf=7, model__min_samples_split=23, model__n_estimators=670; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006234221521788219, model__max_depth=4, model__max_features=0.35, model__max_samples=0.7913485977701479, model__min_samples_leaf=9, model__min_samples_split=38, model__n_estimators=1102; total time=   2.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006234221521788219, model__max_depth=4, model__max_features=0.35, model__max_samples=0.7913485977701479, model__min_samples_leaf=9, model__min_samples_split=38, model__n_estimators=1102; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01684569549189997, model__max_depth=6, model__max_features=0.35, model__max_samples=0.7383025826006351, model__min_samples_leaf=7, model__min_samples_split=23, model__n_estimators=670; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01684569549189997, model__max_depth=6, model__max_features=0.35, model__max_samples=0.7383025826006351, model__min_samples_leaf=7, model__min_samples_split=23, model__n_estimators=670; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01684569549189997, model__max_depth=6, model__max_features=0.35, model__max_samples=0.7383025826006351, model__min_samples_leaf=7, model__min_samples_split=23, model__n_estimators=670; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006234221521788219, model__max_depth=4, model__max_features=0.35, model__max_samples=0.7913485977701479, model__min_samples_leaf=9, model__min_samples_split=38, model__n_estimators=1102; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006234221521788219, model__max_depth=4, model__max_features=0.35, model__max_samples=0.7913485977701479, model__min_samples_leaf=9, model__min_samples_split=38, model__n_estimators=1102; total time=   2.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006234221521788219, model__max_depth=4, model__max_features=0.35, model__max_samples=0.7913485977701479, model__min_samples_leaf=9, model__min_samples_split=38, model__n_estimators=1102; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014946402202747618, model__max_depth=5, model__max_features=0.25, model__max_samples=0.8053629079823468, model__min_samples_leaf=12, model__min_samples_split=37, model__n_estimators=587; total time=   0.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014946402202747618, model__max_depth=5, model__max_features=0.25, model__max_samples=0.8053629079823468, model__min_samples_leaf=12, model__min_samples_split=37, model__n_estimators=587; total time=   1.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014946402202747618, model__max_depth=5, model__max_features=0.25, model__max_samples=0.8053629079823468, model__min_samples_leaf=12, model__min_samples_split=37, model__n_estimators=587; total time=   1.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00176985004103839, model__max_depth=5, model__max_features=sqrt, model__max_samples=0.6158295511186883, model__min_samples_leaf=11, model__min_samples_split=30, model__n_estimators=1119; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00176985004103839, model__max_depth=5, model__max_features=sqrt, model__max_samples=0.6158295511186883, model__min_samples_leaf=11, model__min_samples_split=30, model__n_estimators=1119; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014946402202747618, model__max_depth=5, model__max_features=0.25, model__max_samples=0.8053629079823468, model__min_samples_leaf=12, model__min_samples_split=37, model__n_estimators=587; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014946402202747618, model__max_depth=5, model__max_features=0.25, model__max_samples=0.8053629079823468, model__min_samples_leaf=12, model__min_samples_split=37, model__n_estimators=587; total time=   1.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00176985004103839, model__max_depth=5, model__max_features=sqrt, model__max_samples=0.6158295511186883, model__min_samples_leaf=11, model__min_samples_split=30, model__n_estimators=1119; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00176985004103839, model__max_depth=5, model__max_features=sqrt, model__max_samples=0.6158295511186883, model__min_samples_leaf=11, model__min_samples_split=30, model__n_estimators=1119; total time=   2.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00176985004103839, model__max_depth=5, model__max_features=sqrt, model__max_samples=0.6158295511186883, model__min_samples_leaf=11, model__min_samples_split=30, model__n_estimators=1119; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01085392166316497, model__max_depth=3, model__max_features=0.25, model__max_samples=0.8807689432639139, model__min_samples_leaf=4, model__min_samples_split=34, model__n_estimators=920; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01085392166316497, model__max_depth=3, model__max_features=0.25, model__max_samples=0.8807689432639139, model__min_samples_leaf=4, model__min_samples_split=34, model__n_estimators=920; total time=   1.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01085392166316497, model__max_depth=3, model__max_features=0.25, model__max_samples=0.8807689432639139, model__min_samples_leaf=4, model__min_samples_split=34, model__n_estimators=920; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014226839054973, model__max_depth=5, model__max_features=0.25, model__max_samples=0.812085991173354, model__min_samples_leaf=13, model__min_samples_split=16, model__n_estimators=440; total time=   1.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.015444895385933148, model__max_depth=6, model__max_features=sqrt, model__max_samples=0.6019327409932608, model__min_samples_leaf=14, model__min_samples_split=28, model__n_estimators=992; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01085392166316497, model__max_depth=3, model__max_features=0.25, model__max_samples=0.8807689432639139, model__min_samples_leaf=4, model__min_samples_split=34, model__n_estimators=920; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.015444895385933148, model__max_depth=6, model__max_features=sqrt, model__max_samples=0.6019327409932608, model__min_samples_leaf=14, model__min_samples_split=28, model__n_estimators=992; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01085392166316497, model__max_depth=3, model__max_features=0.25, model__max_samples=0.8807689432639139, model__min_samples_leaf=4, model__min_samples_split=34, model__n_estimators=920; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014226839054973, model__max_depth=5, model__max_features=0.25, model__max_samples=0.812085991173354, model__min_samples_leaf=13, model__min_samples_split=16, model__n_estimators=440; total time=   1.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.015444895385933148, model__max_depth=6, model__max_features=sqrt, model__max_samples=0.6019327409932608, model__min_samples_leaf=14, model__min_samples_split=28, model__n_estimators=992; total time=   2.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.015444895385933148, model__max_depth=6, model__max_features=sqrt, model__max_samples=0.6019327409932608, model__min_samples_leaf=14, model__min_samples_split=28, model__n_estimators=992; total time=   2.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014226839054973, model__max_depth=5, model__max_features=0.25, model__max_samples=0.812085991173354, model__min_samples_leaf=13, model__min_samples_split=16, model__n_estimators=440; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.015444895385933148, model__max_depth=6, model__max_features=sqrt, model__max_samples=0.6019327409932608, model__min_samples_leaf=14, model__min_samples_split=28, model__n_estimators=992; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014226839054973, model__max_depth=5, model__max_features=0.25, model__max_samples=0.812085991173354, model__min_samples_leaf=13, model__min_samples_split=16, model__n_estimators=440; total time=   1.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014226839054973, model__max_depth=5, model__max_features=0.25, model__max_samples=0.812085991173354, model__min_samples_leaf=13, model__min_samples_split=16, model__n_estimators=440; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018299193510875614, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7573077359483711, model__min_samples_leaf=4, model__min_samples_split=25, model__n_estimators=902; total time=   1.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006219646434313244, model__max_depth=6, model__max_features=0.25, model__max_samples=0.8553621624183224, model__min_samples_leaf=11, model__min_samples_split=31, model__n_estimators=946; total time=   1.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018299193510875614, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7573077359483711, model__min_samples_leaf=4, model__min_samples_split=25, model__n_estimators=902; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006219646434313244, model__max_depth=6, model__max_features=0.25, model__max_samples=0.8553621624183224, model__min_samples_leaf=11, model__min_samples_split=31, model__n_estimators=946; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018299193510875614, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7573077359483711, model__min_samples_leaf=4, model__min_samples_split=25, model__n_estimators=902; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018299193510875614, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7573077359483711, model__min_samples_leaf=4, model__min_samples_split=25, model__n_estimators=902; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018299193510875614, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7573077359483711, model__min_samples_leaf=4, model__min_samples_split=25, model__n_estimators=902; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006219646434313244, model__max_depth=6, model__max_features=0.25, model__max_samples=0.8553621624183224, model__min_samples_leaf=11, model__min_samples_split=31, model__n_estimators=946; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.009444298503238985, model__max_depth=3, model__max_features=0.5, model__max_samples=0.8496356755280482, model__min_samples_leaf=4, model__min_samples_split=14, model__n_estimators=617; total time=   1.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.009444298503238985, model__max_depth=3, model__max_features=0.5, model__max_samples=0.8496356755280482, model__min_samples_leaf=4, model__min_samples_split=14, model__n_estimators=617; total time=   1.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006219646434313244, model__max_depth=6, model__max_features=0.25, model__max_samples=0.8553621624183224, model__min_samples_leaf=11, model__min_samples_split=31, model__n_estimators=946; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.009444298503238985, model__max_depth=3, model__max_features=0.5, model__max_samples=0.8496356755280482, model__min_samples_leaf=4, model__min_samples_split=14, model__n_estimators=617; total time=   1.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.009444298503238985, model__max_depth=3, model__max_features=0.5, model__max_samples=0.8496356755280482, model__min_samples_leaf=4, model__min_samples_split=14, model__n_estimators=617; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.009444298503238985, model__max_depth=3, model__max_features=0.5, model__max_samples=0.8496356755280482, model__min_samples_leaf=4, model__min_samples_split=14, model__n_estimators=617; total time=   1.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006219646434313244, model__max_depth=6, model__max_features=0.25, model__max_samples=0.8553621624183224, model__min_samples_leaf=11, model__min_samples_split=31, model__n_estimators=946; total time=   2.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004719698394979115, model__max_depth=4, model__max_features=0.5, model__max_samples=0.614151756338451, model__min_samples_leaf=18, model__min_samples_split=24, model__n_estimators=953; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004719698394979115, model__max_depth=4, model__max_features=0.5, model__max_samples=0.614151756338451, model__min_samples_leaf=18, model__min_samples_split=24, model__n_estimators=953; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004719698394979115, model__max_depth=4, model__max_features=0.5, model__max_samples=0.614151756338451, model__min_samples_leaf=18, model__min_samples_split=24, model__n_estimators=953; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.008786730037315402, model__max_depth=5, model__max_features=0.5, model__max_samples=0.9135172584857317, model__min_samples_leaf=4, model__min_samples_split=29, model__n_estimators=495; total time=   1.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.008786730037315402, model__max_depth=5, model__max_features=0.5, model__max_samples=0.9135172584857317, model__min_samples_leaf=4, model__min_samples_split=29, model__n_estimators=495; total time=   1.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.008786730037315402, model__max_depth=5, model__max_features=0.5, model__max_samples=0.9135172584857317, model__min_samples_leaf=4, model__min_samples_split=29, model__n_estimators=495; total time=   1.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.008786730037315402, model__max_depth=5, model__max_features=0.5, model__max_samples=0.9135172584857317, model__min_samples_leaf=4, model__min_samples_split=29, model__n_estimators=495; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004719698394979115, model__max_depth=4, model__max_features=0.5, model__max_samples=0.614151756338451, model__min_samples_leaf=18, model__min_samples_split=24, model__n_estimators=953; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004719698394979115, model__max_depth=4, model__max_features=0.5, model__max_samples=0.614151756338451, model__min_samples_leaf=18, model__min_samples_split=24, model__n_estimators=953; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.008786730037315402, model__max_depth=5, model__max_features=0.5, model__max_samples=0.9135172584857317, model__min_samples_leaf=4, model__min_samples_split=29, model__n_estimators=495; total time=   1.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.013910321728522551, model__max_depth=3, model__max_features=0.5, model__max_samples=0.811546082747236, model__min_samples_leaf=18, model__min_samples_split=20, model__n_estimators=940; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004575963309832449, model__max_depth=6, model__max_features=0.5, model__max_samples=0.7014130085198188, model__min_samples_leaf=9, model__min_samples_split=37, model__n_estimators=977; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.013910321728522551, model__max_depth=3, model__max_features=0.5, model__max_samples=0.811546082747236, model__min_samples_leaf=18, model__min_samples_split=20, model__n_estimators=940; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.013910321728522551, model__max_depth=3, model__max_features=0.5, model__max_samples=0.811546082747236, model__min_samples_leaf=18, model__min_samples_split=20, model__n_estimators=940; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.013910321728522551, model__max_depth=3, model__max_features=0.5, model__max_samples=0.811546082747236, model__min_samples_leaf=18, model__min_samples_split=20, model__n_estimators=940; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004575963309832449, model__max_depth=6, model__max_features=0.5, model__max_samples=0.7014130085198188, model__min_samples_leaf=9, model__min_samples_split=37, model__n_estimators=977; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.013910321728522551, model__max_depth=3, model__max_features=0.5, model__max_samples=0.811546082747236, model__min_samples_leaf=18, model__min_samples_split=20, model__n_estimators=940; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004575963309832449, model__max_depth=6, model__max_features=0.5, model__max_samples=0.7014130085198188, model__min_samples_leaf=9, model__min_samples_split=37, model__n_estimators=977; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004575963309832449, model__max_depth=6, model__max_features=0.5, model__max_samples=0.7014130085198188, model__min_samples_leaf=9, model__min_samples_split=37, model__n_estimators=977; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004575963309832449, model__max_depth=6, model__max_features=0.5, model__max_samples=0.7014130085198188, model__min_samples_leaf=9, model__min_samples_split=37, model__n_estimators=977; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0037314011777207167, model__max_depth=4, model__max_features=0.35, model__max_samples=0.7887697846704778, model__min_samples_leaf=13, model__min_samples_split=32, model__n_estimators=747; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0037314011777207167, model__max_depth=4, model__max_features=0.35, model__max_samples=0.7887697846704778, model__min_samples_leaf=13, model__min_samples_split=32, model__n_estimators=747; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.012487080962675865, model__max_depth=4, model__max_features=0.25, model__max_samples=0.6369229909405947, model__min_samples_leaf=15, model__min_samples_split=37, model__n_estimators=1019; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.012487080962675865, model__max_depth=4, model__max_features=0.25, model__max_samples=0.6369229909405947, model__min_samples_leaf=15, model__min_samples_split=37, model__n_estimators=1019; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.012487080962675865, model__max_depth=4, model__max_features=0.25, model__max_samples=0.6369229909405947, model__min_samples_leaf=15, model__min_samples_split=37, model__n_estimators=1019; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0037314011777207167, model__max_depth=4, model__max_features=0.35, model__max_samples=0.7887697846704778, model__min_samples_leaf=13, model__min_samples_split=32, model__n_estimators=747; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0037314011777207167, model__max_depth=4, model__max_features=0.35, model__max_samples=0.7887697846704778, model__min_samples_leaf=13, model__min_samples_split=32, model__n_estimators=747; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.012487080962675865, model__max_depth=4, model__max_features=0.25, model__max_samples=0.6369229909405947, model__min_samples_leaf=15, model__min_samples_split=37, model__n_estimators=1019; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.012487080962675865, model__max_depth=4, model__max_features=0.25, model__max_samples=0.6369229909405947, model__min_samples_leaf=15, model__min_samples_split=37, model__n_estimators=1019; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0037314011777207167, model__max_depth=4, model__max_features=0.35, model__max_samples=0.7887697846704778, model__min_samples_leaf=13, model__min_samples_split=32, model__n_estimators=747; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.007125956761539498, model__max_depth=4, model__max_features=0.25, model__max_samples=0.6952462872846223, model__min_samples_leaf=14, model__min_samples_split=39, model__n_estimators=1032; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.007125956761539498, model__max_depth=4, model__max_features=0.25, model__max_samples=0.6952462872846223, model__min_samples_leaf=14, model__min_samples_split=39, model__n_estimators=1032; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.007125956761539498, model__max_depth=4, model__max_features=0.25, model__max_samples=0.6952462872846223, model__min_samples_leaf=14, model__min_samples_split=39, model__n_estimators=1032; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.007125956761539498, model__max_depth=4, model__max_features=0.25, model__max_samples=0.6952462872846223, model__min_samples_leaf=14, model__min_samples_split=39, model__n_estimators=1032; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.016360295318449864, model__max_depth=3, model__max_features=0.5, model__max_samples=0.6024332456859167, model__min_samples_leaf=11, model__min_samples_split=36, model__n_estimators=1048; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.016360295318449864, model__max_depth=3, model__max_features=0.5, model__max_samples=0.6024332456859167, model__min_samples_leaf=11, model__min_samples_split=36, model__n_estimators=1048; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.007125956761539498, model__max_depth=4, model__max_features=0.25, model__max_samples=0.6952462872846223, model__min_samples_leaf=14, model__min_samples_split=39, model__n_estimators=1032; total time=   2.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.016360295318449864, model__max_depth=3, model__max_features=0.5, model__max_samples=0.6024332456859167, model__min_samples_leaf=11, model__min_samples_split=36, model__n_estimators=1048; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.016360295318449864, model__max_depth=3, model__max_features=0.5, model__max_samples=0.6024332456859167, model__min_samples_leaf=11, model__min_samples_split=36, model__n_estimators=1048; total time=   2.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.009696599427179665, model__max_depth=3, model__max_features=0.5, model__max_samples=0.6942943168294825, model__min_samples_leaf=11, model__min_samples_split=24, model__n_estimators=773; total time=   1.7s[CV] END model__bootstrap=True, model__ccp_alpha=0.016360295318449864, model__max_depth=3, model__max_features=0.5, model__max_samples=0.6024332456859167, model__min_samples_leaf=11, model__min_samples_split=36, model__n_estimators=1048; total time=   3.3s
#
# [CV] END model__bootstrap=True, model__ccp_alpha=0.009696599427179665, model__max_depth=3, model__max_features=0.5, model__max_samples=0.6942943168294825, model__min_samples_leaf=11, model__min_samples_split=24, model__n_estimators=773; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.009696599427179665, model__max_depth=3, model__max_features=0.5, model__max_samples=0.6942943168294825, model__min_samples_leaf=11, model__min_samples_split=24, model__n_estimators=773; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004375284391461405, model__max_depth=6, model__max_features=0.25, model__max_samples=0.7413426598703142, model__min_samples_leaf=17, model__min_samples_split=26, model__n_estimators=841; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.009696599427179665, model__max_depth=3, model__max_features=0.5, model__max_samples=0.6942943168294825, model__min_samples_leaf=11, model__min_samples_split=24, model__n_estimators=773; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.009696599427179665, model__max_depth=3, model__max_features=0.5, model__max_samples=0.6942943168294825, model__min_samples_leaf=11, model__min_samples_split=24, model__n_estimators=773; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004375284391461405, model__max_depth=6, model__max_features=0.25, model__max_samples=0.7413426598703142, model__min_samples_leaf=17, model__min_samples_split=26, model__n_estimators=841; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004375284391461405, model__max_depth=6, model__max_features=0.25, model__max_samples=0.7413426598703142, model__min_samples_leaf=17, model__min_samples_split=26, model__n_estimators=841; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004375284391461405, model__max_depth=6, model__max_features=0.25, model__max_samples=0.7413426598703142, model__min_samples_leaf=17, model__min_samples_split=26, model__n_estimators=841; total time=   1.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.004375284391461405, model__max_depth=6, model__max_features=0.25, model__max_samples=0.7413426598703142, model__min_samples_leaf=17, model__min_samples_split=26, model__n_estimators=841; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019248945898842226, model__max_depth=4, model__max_features=0.5, model__max_samples=0.7740369770623349, model__min_samples_leaf=4, model__min_samples_split=14, model__n_estimators=1024; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019248945898842226, model__max_depth=4, model__max_features=0.5, model__max_samples=0.7740369770623349, model__min_samples_leaf=4, model__min_samples_split=14, model__n_estimators=1024; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019248945898842226, model__max_depth=4, model__max_features=0.5, model__max_samples=0.7740369770623349, model__min_samples_leaf=4, model__min_samples_split=14, model__n_estimators=1024; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019248945898842226, model__max_depth=4, model__max_features=0.5, model__max_samples=0.7740369770623349, model__min_samples_leaf=4, model__min_samples_split=14, model__n_estimators=1024; total time=   2.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019248945898842226, model__max_depth=4, model__max_features=0.5, model__max_samples=0.7740369770623349, model__min_samples_leaf=4, model__min_samples_split=14, model__n_estimators=1024; total time=   2.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019954809700978838, model__max_depth=5, model__max_features=0.25, model__max_samples=0.9418152345414285, model__min_samples_leaf=15, model__min_samples_split=31, model__n_estimators=1135; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019954809700978838, model__max_depth=5, model__max_features=0.25, model__max_samples=0.9418152345414285, model__min_samples_leaf=15, model__min_samples_split=31, model__n_estimators=1135; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019954809700978838, model__max_depth=5, model__max_features=0.25, model__max_samples=0.9418152345414285, model__min_samples_leaf=15, model__min_samples_split=31, model__n_estimators=1135; total time=   2.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019954809700978838, model__max_depth=5, model__max_features=0.25, model__max_samples=0.9418152345414285, model__min_samples_leaf=15, model__min_samples_split=31, model__n_estimators=1135; total time=   2.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019954809700978838, model__max_depth=5, model__max_features=0.25, model__max_samples=0.9418152345414285, model__min_samples_leaf=15, model__min_samples_split=31, model__n_estimators=1135; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01105786178142656, model__max_depth=5, model__max_features=sqrt, model__max_samples=0.6282986642164503, model__min_samples_leaf=11, model__min_samples_split=36, model__n_estimators=800; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018165317719333076, model__max_depth=5, model__max_features=0.35, model__max_samples=0.6507132052319281, model__min_samples_leaf=15, model__min_samples_split=35, model__n_estimators=1071; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018165317719333076, model__max_depth=5, model__max_features=0.35, model__max_samples=0.6507132052319281, model__min_samples_leaf=15, model__min_samples_split=35, model__n_estimators=1071; total time=   2.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018165317719333076, model__max_depth=5, model__max_features=0.35, model__max_samples=0.6507132052319281, model__min_samples_leaf=15, model__min_samples_split=35, model__n_estimators=1071; total time=   2.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01105786178142656, model__max_depth=5, model__max_features=sqrt, model__max_samples=0.6282986642164503, model__min_samples_leaf=11, model__min_samples_split=36, model__n_estimators=800; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018165317719333076, model__max_depth=5, model__max_features=0.35, model__max_samples=0.6507132052319281, model__min_samples_leaf=15, model__min_samples_split=35, model__n_estimators=1071; total time=   2.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018165317719333076, model__max_depth=5, model__max_features=0.35, model__max_samples=0.6507132052319281, model__min_samples_leaf=15, model__min_samples_split=35, model__n_estimators=1071; total time=   2.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01105786178142656, model__max_depth=5, model__max_features=sqrt, model__max_samples=0.6282986642164503, model__min_samples_leaf=11, model__min_samples_split=36, model__n_estimators=800; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01105786178142656, model__max_depth=5, model__max_features=sqrt, model__max_samples=0.6282986642164503, model__min_samples_leaf=11, model__min_samples_split=36, model__n_estimators=800; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01105786178142656, model__max_depth=5, model__max_features=sqrt, model__max_samples=0.6282986642164503, model__min_samples_leaf=11, model__min_samples_split=36, model__n_estimators=800; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014564326972237192, model__max_depth=6, model__max_features=0.25, model__max_samples=0.8213070407077527, model__min_samples_leaf=9, model__min_samples_split=31, model__n_estimators=910; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014564326972237192, model__max_depth=6, model__max_features=0.25, model__max_samples=0.8213070407077527, model__min_samples_leaf=9, model__min_samples_split=31, model__n_estimators=910; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014564326972237192, model__max_depth=6, model__max_features=0.25, model__max_samples=0.8213070407077527, model__min_samples_leaf=9, model__min_samples_split=31, model__n_estimators=910; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0018057954010881662, model__max_depth=3, model__max_features=0.25, model__max_samples=0.7122730227401075, model__min_samples_leaf=9, model__min_samples_split=25, model__n_estimators=748; total time=   1.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0018057954010881662, model__max_depth=3, model__max_features=0.25, model__max_samples=0.7122730227401075, model__min_samples_leaf=9, model__min_samples_split=25, model__n_estimators=748; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0018057954010881662, model__max_depth=3, model__max_features=0.25, model__max_samples=0.7122730227401075, model__min_samples_leaf=9, model__min_samples_split=25, model__n_estimators=748; total time=   1.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014564326972237192, model__max_depth=6, model__max_features=0.25, model__max_samples=0.8213070407077527, model__min_samples_leaf=9, model__min_samples_split=31, model__n_estimators=910; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014564326972237192, model__max_depth=6, model__max_features=0.25, model__max_samples=0.8213070407077527, model__min_samples_leaf=9, model__min_samples_split=31, model__n_estimators=910; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0018057954010881662, model__max_depth=3, model__max_features=0.25, model__max_samples=0.7122730227401075, model__min_samples_leaf=9, model__min_samples_split=25, model__n_estimators=748; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0018057954010881662, model__max_depth=3, model__max_features=0.25, model__max_samples=0.7122730227401075, model__min_samples_leaf=9, model__min_samples_split=25, model__n_estimators=748; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.017167176096274397, model__max_depth=6, model__max_features=0.5, model__max_samples=0.6770843666479419, model__min_samples_leaf=13, model__min_samples_split=12, model__n_estimators=910; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.017167176096274397, model__max_depth=6, model__max_features=0.5, model__max_samples=0.6770843666479419, model__min_samples_leaf=13, model__min_samples_split=12, model__n_estimators=910; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.017167176096274397, model__max_depth=6, model__max_features=0.5, model__max_samples=0.6770843666479419, model__min_samples_leaf=13, model__min_samples_split=12, model__n_estimators=910; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.017167176096274397, model__max_depth=6, model__max_features=0.5, model__max_samples=0.6770843666479419, model__min_samples_leaf=13, model__min_samples_split=12, model__n_estimators=910; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.017167176096274397, model__max_depth=6, model__max_features=0.5, model__max_samples=0.6770843666479419, model__min_samples_leaf=13, model__min_samples_split=12, model__n_estimators=910; total time=   2.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.010355027010549602, model__max_depth=6, model__max_features=0.25, model__max_samples=0.8364915409637482, model__min_samples_leaf=12, model__min_samples_split=34, model__n_estimators=550; total time=   1.4s
# ...
# [CV] END model__bootstrap=True, model__ccp_alpha=0.005304047353634509, model__max_depth=4, model__max_features=0.35, model__max_samples=0.9405536941633559, model__min_samples_leaf=16, model__min_samples_split=28, model__n_estimators=837; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.005304047353634509, model__max_depth=4, model__max_features=0.35, model__max_samples=0.9405536941633559, model__min_samples_leaf=16, model__min_samples_split=28, model__n_estimators=837; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01812197575437108, model__max_depth=5, model__max_features=0.35, model__max_samples=0.7225274426931365, model__min_samples_leaf=4, model__min_samples_split=37, model__n_estimators=880; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01812197575437108, model__max_depth=5, model__max_features=0.35, model__max_samples=0.7225274426931365, model__min_samples_leaf=4, model__min_samples_split=37, model__n_estimators=880; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01812197575437108, model__max_depth=5, model__max_features=0.35, model__max_samples=0.7225274426931365, model__min_samples_leaf=4, model__min_samples_split=37, model__n_estimators=880; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01812197575437108, model__max_depth=5, model__max_features=0.35, model__max_samples=0.7225274426931365, model__min_samples_leaf=4, model__min_samples_split=37, model__n_estimators=880; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.003542213588140979, model__max_depth=6, model__max_features=0.35, model__max_samples=0.9338750019509056, model__min_samples_leaf=8, model__min_samples_split=15, model__n_estimators=498; total time=   1.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01812197575437108, model__max_depth=5, model__max_features=0.35, model__max_samples=0.7225274426931365, model__min_samples_leaf=4, model__min_samples_split=37, model__n_estimators=880; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00390485975596089, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.6982703268542995, model__min_samples_leaf=6, model__min_samples_split=26, model__n_estimators=911; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00390485975596089, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.6982703268542995, model__min_samples_leaf=6, model__min_samples_split=26, model__n_estimators=911; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00390485975596089, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.6982703268542995, model__min_samples_leaf=6, model__min_samples_split=26, model__n_estimators=911; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.003542213588140979, model__max_depth=6, model__max_features=0.35, model__max_samples=0.9338750019509056, model__min_samples_leaf=8, model__min_samples_split=15, model__n_estimators=498; total time=   1.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00390485975596089, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.6982703268542995, model__min_samples_leaf=6, model__min_samples_split=26, model__n_estimators=911; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.00390485975596089, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.6982703268542995, model__min_samples_leaf=6, model__min_samples_split=26, model__n_estimators=911; total time=   2.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.003542213588140979, model__max_depth=6, model__max_features=0.35, model__max_samples=0.9338750019509056, model__min_samples_leaf=8, model__min_samples_split=15, model__n_estimators=498; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.003542213588140979, model__max_depth=6, model__max_features=0.35, model__max_samples=0.9338750019509056, model__min_samples_leaf=8, model__min_samples_split=15, model__n_estimators=498; total time=   1.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.003542213588140979, model__max_depth=6, model__max_features=0.35, model__max_samples=0.9338750019509056, model__min_samples_leaf=8, model__min_samples_split=15, model__n_estimators=498; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019272399541785057, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.703057112224355, model__min_samples_leaf=8, model__min_samples_split=32, model__n_estimators=560; total time=   1.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019272399541785057, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.703057112224355, model__min_samples_leaf=8, model__min_samples_split=32, model__n_estimators=560; total time=   1.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019272399541785057, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.703057112224355, model__min_samples_leaf=8, model__min_samples_split=32, model__n_estimators=560; total time=   1.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014954375477948279, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7157626066346797, model__min_samples_leaf=17, model__min_samples_split=30, model__n_estimators=1006; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019272399541785057, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.703057112224355, model__min_samples_leaf=8, model__min_samples_split=32, model__n_estimators=560; total time=   1.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014954375477948279, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7157626066346797, model__min_samples_leaf=17, model__min_samples_split=30, model__n_estimators=1006; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014954375477948279, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7157626066346797, model__min_samples_leaf=17, model__min_samples_split=30, model__n_estimators=1006; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014954375477948279, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7157626066346797, model__min_samples_leaf=17, model__min_samples_split=30, model__n_estimators=1006; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014954375477948279, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.7157626066346797, model__min_samples_leaf=17, model__min_samples_split=30, model__n_estimators=1006; total time=   2.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.019272399541785057, model__max_depth=3, model__max_features=sqrt, model__max_samples=0.703057112224355, model__min_samples_leaf=8, model__min_samples_split=32, model__n_estimators=560; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006338440103125553, model__max_depth=6, model__max_features=0.35, model__max_samples=0.7948804418604225, model__min_samples_leaf=18, model__min_samples_split=31, model__n_estimators=969; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006338440103125553, model__max_depth=6, model__max_features=0.35, model__max_samples=0.7948804418604225, model__min_samples_leaf=18, model__min_samples_split=31, model__n_estimators=969; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01860033669621664, model__max_depth=4, model__max_features=sqrt, model__max_samples=0.6731215511653761, model__min_samples_leaf=18, model__min_samples_split=31, model__n_estimators=1062; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006338440103125553, model__max_depth=6, model__max_features=0.35, model__max_samples=0.7948804418604225, model__min_samples_leaf=18, model__min_samples_split=31, model__n_estimators=969; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006338440103125553, model__max_depth=6, model__max_features=0.35, model__max_samples=0.7948804418604225, model__min_samples_leaf=18, model__min_samples_split=31, model__n_estimators=969; total time=   2.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.006338440103125553, model__max_depth=6, model__max_features=0.35, model__max_samples=0.7948804418604225, model__min_samples_leaf=18, model__min_samples_split=31, model__n_estimators=969; total time=   2.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01860033669621664, model__max_depth=4, model__max_features=sqrt, model__max_samples=0.6731215511653761, model__min_samples_leaf=18, model__min_samples_split=31, model__n_estimators=1062; total time=   2.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01860033669621664, model__max_depth=4, model__max_features=sqrt, model__max_samples=0.6731215511653761, model__min_samples_leaf=18, model__min_samples_split=31, model__n_estimators=1062; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01860033669621664, model__max_depth=4, model__max_features=sqrt, model__max_samples=0.6731215511653761, model__min_samples_leaf=18, model__min_samples_split=31, model__n_estimators=1062; total time=   2.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.01860033669621664, model__max_depth=4, model__max_features=sqrt, model__max_samples=0.6731215511653761, model__min_samples_leaf=18, model__min_samples_split=31, model__n_estimators=1062; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.002801680304730481, model__max_depth=5, model__max_features=0.35, model__max_samples=0.9070805751747844, model__min_samples_leaf=4, model__min_samples_split=17, model__n_estimators=792; total time=   2.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.002801680304730481, model__max_depth=5, model__max_features=0.35, model__max_samples=0.9070805751747844, model__min_samples_leaf=4, model__min_samples_split=17, model__n_estimators=792; total time=   1.6s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.002801680304730481, model__max_depth=5, model__max_features=0.35, model__max_samples=0.9070805751747844, model__min_samples_leaf=4, model__min_samples_split=17, model__n_estimators=792; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.002801680304730481, model__max_depth=5, model__max_features=0.35, model__max_samples=0.9070805751747844, model__min_samples_leaf=4, model__min_samples_split=17, model__n_estimators=792; total time=   2.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014049681679742186, model__max_depth=6, model__max_features=0.5, model__max_samples=0.7027571454925726, model__min_samples_leaf=10, model__min_samples_split=35, model__n_estimators=807; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.002801680304730481, model__max_depth=5, model__max_features=0.35, model__max_samples=0.9070805751747844, model__min_samples_leaf=4, model__min_samples_split=17, model__n_estimators=792; total time=   1.9s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014049681679742186, model__max_depth=6, model__max_features=0.5, model__max_samples=0.7027571454925726, model__min_samples_leaf=10, model__min_samples_split=35, model__n_estimators=807; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014049681679742186, model__max_depth=6, model__max_features=0.5, model__max_samples=0.7027571454925726, model__min_samples_leaf=10, model__min_samples_split=35, model__n_estimators=807; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018264811051129426, model__max_depth=4, model__max_features=0.5, model__max_samples=0.7755307031405199, model__min_samples_leaf=16, model__min_samples_split=29, model__n_estimators=720; total time=   1.4s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014049681679742186, model__max_depth=6, model__max_features=0.5, model__max_samples=0.7027571454925726, model__min_samples_leaf=10, model__min_samples_split=35, model__n_estimators=807; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0014188183399985533, model__max_depth=4, model__max_features=sqrt, model__max_samples=0.6177689858637889, model__min_samples_leaf=6, model__min_samples_split=32, model__n_estimators=542; total time=   1.1s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0014188183399985533, model__max_depth=4, model__max_features=sqrt, model__max_samples=0.6177689858637889, model__min_samples_leaf=6, model__min_samples_split=32, model__n_estimators=542; total time=   1.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0014188183399985533, model__max_depth=4, model__max_features=sqrt, model__max_samples=0.6177689858637889, model__min_samples_leaf=6, model__min_samples_split=32, model__n_estimators=542; total time=   1.0s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018264811051129426, model__max_depth=4, model__max_features=0.5, model__max_samples=0.7755307031405199, model__min_samples_leaf=16, model__min_samples_split=29, model__n_estimators=720; total time=   1.8s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018264811051129426, model__max_depth=4, model__max_features=0.5, model__max_samples=0.7755307031405199, model__min_samples_leaf=16, model__min_samples_split=29, model__n_estimators=720; total time=   2.3s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018264811051129426, model__max_depth=4, model__max_features=0.5, model__max_samples=0.7755307031405199, model__min_samples_leaf=16, model__min_samples_split=29, model__n_estimators=720; total time=   1.7s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.014049681679742186, model__max_depth=6, model__max_features=0.5, model__max_samples=0.7027571454925726, model__min_samples_leaf=10, model__min_samples_split=35, model__n_estimators=807; total time=   2.5s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0014188183399985533, model__max_depth=4, model__max_features=sqrt, model__max_samples=0.6177689858637889, model__min_samples_leaf=6, model__min_samples_split=32, model__n_estimators=542; total time=   1.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.0014188183399985533, model__max_depth=4, model__max_features=sqrt, model__max_samples=0.6177689858637889, model__min_samples_leaf=6, model__min_samples_split=32, model__n_estimators=542; total time=   1.2s
# [CV] END model__bootstrap=True, model__ccp_alpha=0.018264811051129426, model__max_depth=4, model__max_features=0.5, model__max_samples=0.7755307031405199, model__min_samples_leaf=16, model__min_samples_split=29, model__n_estimators=720; total time=   1.8s
# RandomizedSearchCV(cv=StratifiedGroupKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                              ('model',
#                                               RandomForestClassifier(n_jobs=-1,
#                                                                      random_state=42))]),
#                    n_iter=60, n_jobs=-1,
#                    param_distributions={'model__bootstrap': [True],
#                                         'model__ccp_alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0...
#                                         'model__max_samples': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x118c74440>,
#                                         'model__min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x118bffb10>,
#                                         'model__min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x118bff890>,
#                                         'model__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x118c74590>},
#                    random_state=42, scoring='f1_macro', verbose=2)

# %%
print("Hyperparameter Tuning result:")
print("Best params:", random_search.best_params_)
print("Best score:", random_search.best_score_)
# Out:
# Hyperparameter Tuning result:
# Best params: {'model__bootstrap': True, 'model__ccp_alpha': np.float64(0.00176985004103839), 'model__max_depth': 5, 'model__max_features': 'sqrt', 'model__max_samples': np.float64(0.6158295511186883), 'model__min_samples_leaf': 11, 'model__min_samples_split': 30, 'model__n_estimators': 1119}
# Best score: 0.852893791963765

# %% [markdown]
# **7. Retrain with best params**

# %%
rfc_best = Pipeline(
    steps=[
        ("scaler", StandardScaler()),
        ("model", RandomForestClassifier(
            random_state=RANDOM_STATE,
            n_jobs=-1,
            n_estimators=random_search.best_params_["model__n_estimators"],
            max_depth=random_search.best_params_["model__max_depth"],
            min_samples_split=random_search.best_params_["model__min_samples_split"],
            min_samples_leaf=random_search.best_params_["model__min_samples_leaf"],
            max_features=random_search.best_params_["model__max_features"],
            bootstrap=random_search.best_params_["model__bootstrap"],
        ))
    ]
)

# %%
# train the best model
rfc_best.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  RandomForestClassifier(max_depth=5, min_samples_leaf=11,
#                                         min_samples_split=30, n_estimators=1119,
#                                         n_jobs=-1, random_state=42))])

# %% [markdown]
# **8. Model Evaluation**

# %%
evaluate_classifier(
    rfc_best,
    X_train,
    y_train,
    X_test,
    y_test,
    model_name="Random Forest - Best Model"
)
# Out:
# Random Forest - Best Model - Train Accuracy: 91.25%
# Random Forest - Best Model - Test Accuracy: 81.41%
#
# ----------------------------------------
# Train Classification Report
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       430
#            1       0.89      0.94      0.92       439
#
#     accuracy                           0.91       869
#    macro avg       0.91      0.91      0.91       869
# weighted avg       0.91      0.91      0.91       869
#
# ----------------------------------------
# Test Classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.71      0.77        69
#            1       0.80      0.90      0.84        87
#
#     accuracy                           0.81       156
#    macro avg       0.82      0.80      0.81       156
# weighted avg       0.82      0.81      0.81       156

# %% [markdown]
# **9. Build a predictive system**

# %%
import pandas as pd

def predict_heart_disease(input_features):

    # create DataFrame with correct column order
    input_df = pd.DataFrame(
        [input_features],
        columns=X_train.columns
    )

    # class prediction
    prediction = rfc_best.predict(input_df)[0]

    # probability prediction (positive class)
    probability = rfc_best.predict_proba(input_df)[0][1]

    # output
    print(f"Predicted class: {prediction}")
    print(f"Heart disease risk probability: {probability:.2%}")

    if prediction == 1:
        print("Diagnosis: High risk of heart disease 🔴")
    else:
        print("Diagnosis: Low risk of heart disease 🟢")

    return prediction, probability

# %%
y_test[y_test==1].head()
# Out:
# 24    1
# 38    1
# 57    1
# 68    1
# 84    1
# Name: target, dtype: int64

# %%
y_test[y_test==0].head()
# Out:
# 4     0
# 8     0
# 17    0
# 43    0
# 53    0
# Name: target, dtype: int64

# %%
# sample unknown data point - access from test data index
test_1 = X_test.loc[24].tolist()
print(test_1)
# Out:
# [42.0, 0.0, 2.0, 120.0, 209.0, 0.0, 1.0, 173.0, 0.0, 0.0, 1.0, 0.0, 2.0]

# %%
predict_heart_disease(test_1)
# Out:
# Predicted class: 1
# Heart disease risk probability: 96.53%
# Diagnosis: High risk of heart disease 🔴
# (np.int64(1), np.float64(0.9653486473533653))

# %%
# sample unknown data point - access from test data index
test_2 = X_test.loc[4].tolist()
print(test_2)
# Out:
# [62.0, 0.0, 0.0, 138.0, 294.0, 1.0, 1.0, 106.0, 0.0, 1.9, 1.0, 3.0, 2.0]

# %%
predict_heart_disease(test_2)
# Out:
# Predicted class: 0
# Heart disease risk probability: 28.52%
# Diagnosis: Low risk of heart disease 🟢
# (np.int64(0), np.float64(0.28519436390232045))
